# %%
download.file("http://www.openintro.org/stat/data/evals.RData",
              destfile = "evals.RData")
load("evals.RData")

normalplot<-function(m,sd,region=0){
  x<-seq(m-3.5*sd,m+3.5*sd,length=1000)
  y<-dnorm(x,m,sd)
  plot(x,y,type="l",xlab="",ylab="")
  z<-x[x>region[1]]
  z<- z[z<region[2]]
  polygon(c(region[1],z,region[2]),c(0,dnorm(z,m,sd),0),col="gray") }

# %% [markdown]
# # 1
#
# The first half of the lab exam involves the data set `evals` involving data from  a random sample of student evaluations at the University of Texas at Austin.
#
# We will be interested in the following variables:
#
# `score` the score on teaching evaluations
# `age` the instuctors age
# `rank` the instructors rank
# `gender` the instructors gender

# %% [markdown]
# # Checking the age data for normality.
#
# ## Histograms
#
# You must produce two histograms for `age`.
# - vary the number of bins
# - at least one of the two histograms must properly display the shape of the datas distribution.

# %% [markdown]
# ## qqplot -- OMIT FALL 2019
#
# Produce a qqplot comparing the `age` data to the normal distribution.

# %% [markdown]
# ## Boxplot
#
# Produce a boxplot for the `age` data.

# %% [markdown]
# # Relationships between variables
#
# ## Scatter plot
#
# Produce a scatter plot comparing `age` and `score`.

# %% [markdown]
# ## Mosaic Plot
#
# Produce a mosaic plot comparing `gender` and `rank`

# %% [markdown]
# ## Side by Side Box plot
#
# Produce side by side box plots comparing `score` and `rank`

# %% [markdown]
# # Statistical Summaries
#
# Compute the following summaries for the variable `score`
#
# ---
# mean=

# %% [markdown]
# standard deviation =

# %% [markdown]
# median=

# %% [markdown]
# minimum score =

# %% [markdown]
# Compute a frequency/contingency table for the `rank` of the instructors split by `gender`.

# %% [markdown]
# # Probabilities
#
# 45% of households own a pet.  In a random sample of 20 homes what is the probability that...
#
#
# ...exactly 6 own a pet?

# %% [markdown]
# ... more than 8 own a pet?

# %% [markdown]
# The distribution of exam scores is approximately normal with a mean of 56 and a standard deviation of 10.
#
# What is the probability that a randomly selected exam has  a score over 50?

# %% [markdown]
# What is the cut off for the highest 10% of the scores.
#
# (Fill in the blank, 10% of students score above ___)

# %% [markdown]
# If I take a random sample of 5 exams, what is the probability that the average from my sample is less than 53?
#
# **Since we are taking a random sample from a normal distribution with a known standard deviation we need to use the normal distribution not a t distribution. **
