# %% [markdown]
# # Worksheet 06 Continuous Probability Distributions

# %% [markdown]
# ## Objectives: ##
# * To become familiar with the R commands used to display a mormal random variable
# * To become familiar with the R commands used to calculate probabilities using a normal random variable

# %% [markdown]
# ## Instructions: ##
# * Do NOT round any of the values.
# * After calculating a probability, in the markdown block, indicate what you have found using approriate probability format AND a sentence. <br> Examples of proper format:
#   * P(X > 4) = 0.52687495122
#   * P(Y < 3) = 0.25447898
#   * P(2 < X < 8) = 0.999587411563
# * After calculating a value that is not a probability, indicate what you have found with a sentence.

# %% [markdown]
# ## Formulae: ##
# * If  $X$  is a normal random variable with a mean of $\mu$ and a standard deviation of $\sigma$ <br>then we write $X \sim N(\mu,\sigma)$. This notation is called the normal short form.
# * $Z$ represents the standard normal distribution and $Z \sim N(0,1)$.
# * The normal probability command `pnorm(`&lt;value&gt; `,` &lt;mean&gt; `,` &lt;sd&gt; `)` is used to determine P(X &lt; value) for a normal random variable with a mean of &lt;mean&gt; and a standard deviation of &lt;sd&gt;. <br>
# * Recall that for continuous data:
#   * P(X = value) = 0
#   * P(X &gt; value) = 1 - P(X &lt; value)
#   * P(lowVal &lt; X &lt; highVal) = P(X &lt; highVal) - P(X &lt; lowVal)
#
#   * If $X$ is a normal random variable then the $P$th percentile is the value $v$ such that $P(X < v) = P/100$.

# %% [markdown]
# ## Tools: ##
#
# ## Data Information: ##
# Suppose a large population of children has a mean height of 95 and a standard deviation of 11.7cm.<br>
# Suppose that the distribution of heights is approximately normal.
# Let $X$ represent the height of a child randomly selected from this population.

# %% [markdown]
# ### Question 1
#
# Use the paper provided to make an accurate normal plot

# %% [markdown]
# ## Question 2. Calculating probabilities ##
# The command `pnorm(` &lt;value&gt; `,` &lt;mean&gt; `,` &lt;sd&gt; `)` is used to determine P(X &lt; value) using the normal probability function<br>with
# * &lt;value&gt;  - is the value of interest
# * &lt;mean&gt;  - is the mean of the normal distribution
# * &lt;sd&gt;  - is the standard deviation of the normal distribution

# %% [markdown]
# For each part, draw the normal distribution with the area of interest shaded then calculate the probability.
# * a. What is the probability that a child's height is less than 105?
# * b. What is the probability that a child's height is above 110?
# * c. What is the probability that a child's height is between 95 and 130?

# %% [markdown]
# ## Question 3. Verifying the 68-95-99.7 rule ##
#
#
# Use $Z$ to verify the 68-95-99.7 rule by shading the appropriate area under the curve then finding the indicated value.
# * a. Determine the probability that $Z$ is within 1 standard deviation of the mean.
# * b. Determine the probability that $Z$ is within 2 standard deviations of the mean.
# * c. Determine the probability that $Z$ is within 3 standard deviations of the mean.

# %% [markdown]
# ## Question 4
#
# The R command `qnorm(` &lt;prob&gt; `,` &lt;mean&gt; `,` &lt;sd&gt; `)` determines $P( X \lt$ value $) =$ &lt;prob&gt;<br>
# Use `qnorm` to determine the required value then write a sentence indicating the meaning of the value.
# Suppose a large population of children has a mean height of 95 and a standard deviation of 11.7cm.<br>
# Suppose that the distribution of heights is approximately normal.
# * a. Fill in the blank. Sixty percent of the children are shorter than ________________.
# * b. What is the lower quartile for this random variable?
# * c. If you want to start a tall kids club that only admits the tallest 15% of students what should you set your cut off for admission at?

# %% [markdown]
# ## Question 5
#
# It is believed that in 2010, 55% of Albertans 15 and over volunteered.
#
# Suppose we all plan to ask a random sample of 100 Albertans 15 and over if they volunteered in the past year.
#
# * a. How many people in my sample should I expect to say yes?   (This is the expected value of the sampling distribution)
# * b. What will the standard deviation of the sampling distribution?
# * c. Determine the probability that less than 54 people in the survey say yes.
# * d.  Use the normal approximation to estimate the probability that less than 54 people in the survey say yes. Draw the normal distribution showing the appropriate section shaded before calculating the probability.
# * e. Determine the probability that the proportion of the sample is more than 55.6%. Compare the two values you get if you find the exact value or the approximate value.
