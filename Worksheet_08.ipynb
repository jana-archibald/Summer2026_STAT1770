# %% [markdown]
# # Worksheet 7: Hypothesis Tests One Proportion #

# %% [markdown]
# ## Objectives: ##
# To become familiar with hypothesis tests one proportion and practice using the formula provided below.

# %% [markdown]
# ## Instructions: ##
# * Do NOT round any of the values unless your are explicitly told to do so in the question.
# * You can compute the required values using R as your calculator.

# %% [markdown]
# ## Formulae: ##
# - Z-statistic: $Z=\frac{\hat{p}-p}{SE_{\hat{p}}}$
# Standard error for $\hat{p}$
#
# $$SE(\hat{p})=\sqrt{\frac{p(1-p)}{n}}$$

# %% [markdown]
# ## Tools: ##
#
# If the conditions for inference are reasonable, we can either calculate the standard error, $SE_{\hat{p}}$ and construct the interval by hand, or allow one of the functions in R, such as `binom.test`, to do it for us.
#
# The `binom.test` function relies upon several arguments. For constructing confidence intervals for proportions, the following arguments are important:
# * `x` - number of successes
# * `n` - number of trials
# * `p` - The hypothesised probability of success (We will talk about this on Wednesday.)
# * `conf.level` - confidence level desired

# %%
download.file("http://www.openintro.org/data/rda/ebola_survey.rda", destfile = "ebola_survey.rda")
load("ebola_survey.rda")

# %% [markdown]
# ### Data Set:
#
# Today we will be using data from a 2014 survey of 1,042 New York city residents regarding their opinion of a mandatory quarantine for those exposed to Ebola.
#
# In New York City on October 23rd, 2014, a doctor who had recently been treating Ebola patients in Guinea went to the hospital with a slight fever and was subsequently diagnosed with Ebola. Soon thereafter, an NBC 4 New York/The Wall Street Journal/Marist Poll asked New Yorkers whether they favored a "mandatory 21-day quarantine for anyone who has come in contact with an Ebola patient". This poll included responses of a random sample of 1,042 New York adults contacted between October 26th and 28th, 2014.
#
#
# #### Name: ####
# * `ebola_survey` - opinion data from the survey of 1,042 New Yorkers.
#
# #### Variables: ####
# * `quarantine` - indicates whether the respondent is in `favor` or `against` the mandatory quarantine

# %% [markdown]
# ## Question 1. Practice with p-values##

# %% [markdown]
# In this question we will be looking at only the last part of hypothesis tests. Mainly computing the p-value and writting a conlclusion.
#
#
# ### Hypothesis Test A
#
# Prepare:
#
# - $H_0: p = 0.1$
# - $H_a: p <0.1 $
# - $\alpha=0.05$
# - n=200
#
# Check:
#
# Independence
# - Random sample $\checkmark$
# - Less than 10% $\checkmark$
# - Independent data gathering? $\checkmark$
#
# Sample Size
#  - At least 10 successes 0.1*200=20>10$\checkmark$
#  - At least 10 failures   0.9*200=180>10$\checkmark$
#
#  Calculate:
#
# The study was completed and observed 14 successses in the 200 trials.
#
# $\hat{p}=0.07$
#
# $SE(\hat{p})=\sqrt{\frac{0.1\times 0.9}{200}}=0.0212132034355964$
#
# * a. Plot the area corresponding to the p-value by running the folowing code.
# * b. Calculate the z score
#
# * c. Compute the p-value using either the exact method (binomial) or the normal approximation.
#
#  - You could even try both.
# * d. Write the conclusion for this hypothesis test.

# %% [markdown]
# ### Answer 1.a. ##

# %%
barplot(dbinom(c(0:30),200,0.1),
       names.arg=c(0:30),
         xlab="Number of Successes",ylab="Probability",
        col=append(c(1:15)/c(1:15),0*c(15:30)))
# Out:
# plot without title

# %%
Calculate the proportion.
# Out:
# Error in parse(text = input): <text>:1:11: unexpected symbol
# 1: Calculate the
#               ^
# Traceback:

# %% [markdown]
# Answer with a sentence.

# %% [markdown]
# ### Answer 1.b. ##

# %% [markdown]
# ### Answer 1.c. ##

# %% [markdown]
# ### Answer 1.d. ##

# %% [markdown]
# Answer with a sentence.

# %% [markdown]
# In this question we will be looking at only the last part of hypothesis tests. Mainly computing the p-value and writting a conlclusion.
#
#
# ### Part b)
#
# Prepare:
#
# - $H_0: p  =  0.4$
# - $H_a: p  \neq 0.4 $
# - $\alpha=0.05$
# - n=450
#
# Check:
#
# Independence
# - Random sample $\checkmark$
# - Less than 10% $\checkmark$
# - Independent data gathering? $\checkmark$
#
# Sample Size
#  - At least 10 successes  450*0.4=180>10$\checkmark$
#  - At least 10 failures   450*0.6=270>10$\checkmark$
#
#  Calculate:
#
# The study was completed and observed 192 successses in the 450 trials.
#
# $\hat{p}=\frac{202}{450}=0.448888888888889$
#
# $SE(\hat{p})$ `=sqrt(0.4*0.6/450)=0.023094010767585`
#
# * a. Plot the area on paper
# * b. Calculate the z score
# * c. Compute the p-value using either the exact method (binomial) or the normal approximation.
#
#  - You could even try both.
# * Write the conclusion for this hypothesis test.

# %% [markdown]
# ## Question 3 Using R commands for hypothesis tests.

# %% [markdown]
# ## Working with a data set
#
# ### Data Set:
#
# Today we will be using data from a 2014 survey of 1,042 New York city residents regarding their opinion of a mandatory quarantine for those exposed to Ebola.
#
# In New York City on October 23rd, 2014, a doctor who had recently been treating Ebola patients in Guinea went to the hospital with a slight fever and was subsequently diagnosed with Ebola. Soon thereafter, an NBC 4 New York/The Wall Street Journal/Marist Poll asked New Yorkers whether they favored a "mandatory 21-day quarantine for anyone who has come in contact with an Ebola patient". This poll included responses of a random sample of 1,042 New York adults contacted between October 26th and 28th, 2014.
#
#
# #### Name: ####
# * `ebola_survey` - opinion data from the survey of 1,042 New Yorkers.
#
# #### Variables: ####
# * `quarantine` - indicates whether the respondent is in `favor` or `against` the mandatory quarantine

# %%
download.file("http://www.openintro.org/data/rda/ebola_survey.rda", destfile = "ebola_survey.rda")
load("ebola_survey.rda")

# %% [markdown]
#  Suppose that a previous study suggested that support for a mandatory quarantine was 0.80 or 80%. However, city officials might believe that recent events have meant that support for a mandatory quarantine has increased. Then the null hypothesis would be that support remains the same as it was before, $p = 0.80$. The  null hypothesis represents the status quo, or no change, and we will stick with this unless there is sufficient evidence in the new survey to reject this. The alternative would be that support has increased, $p > 0.80$. This represents the claim that must be "proven" based upon the evidence in the new survey. These hypotheses would be established before any data is collected.

# %% [markdown]
# Alternately, when we have access we can get R to calculate confidence intervals.
#
#
# The `binom.test` function relies upon several arguments. For constructing confidence intervals for proportions, the following arguments are important:
# * `x` - number of successes
# * `n` - number of trials
# * `p` - The hypothesised probability of success
# * `conf.level` - confidence level desired
# * `alternative` - the alternative hypothesis is either "greater", "less", or "two.sided"
#
# * If you use a table from a dataset that has two entries, you can use that in place of `x` and `n` for the data.

# %%
table(ebola_survey$quarantine)

# %% [markdown]
# You now know what p the hypothesised probability of sucess means. Use binom.test to complete the compute part of a hypothesis test.

# %% [markdown]
# The `prop.test` function may be used to test the hypotheses
#
# $H_0: p = 0.8$ vs $H_A: p > 0.8$
#
# The `prop.test` function may be used for hypothesis tests with the appropriate arguments:
# * `x` - number of successes
# * `n` - number of trials
# * `p` - the value of the proportion stated in the null hypothesis
# * `alternative` - the alternative hypothesis is either "greater", "less", or "two.sided"
# * `correct` - a logical argument determining whether a continuity correction should be applied. We will not employ the continuity correction

# %% [markdown]
# ## Conclude
#
# Write a sentence sumarising your calculations above.

# %% [markdown]
# ---
# ---
# #### This tutorial is released under a Creative Commons Attribution-ShareAlike 3.0 Unported.
#
# This tutorial has been adapted from a lab that  was adapted for OpenIntro by Andrew Bray and Mine Çetinkaya-Rundel from a lab written by Mark Hansen of UCLA Statistics.
#
# ---
# ---
